# %% [markdown]
# # Full waveform inversion by model extension (FWIME)
# * ## Application to the "Salt model"
# * ## Created from the BP 2004 benchmark (Billette and Brandsberg-Dahl, 2004)
#
# ---
# * Authors: Guillaume Barnier (barnier@gmail.com), Ettore Biondi (ebiondi@caltech.edu), and Stuart Farris (sfarris@sep.stanford.edu)
# * Date: 05/12/2022
# * Feel free to contact us for any questions or bugs to report
#
# ---
# # About the authors
# * [**Guillaume Barnier**](https://www.linkedin.com/in/guillaume-barnier/)
#     * Ph.D. student at Stanford University in the Stanford Exporation Project (SEP) group
#     * Research interests: seismic imaging, velocity model building, optimization of large-scale non-convex inverse problems, and machine learning
#     * Guillaume's [personal website](https://gbarnier.github.io)
# * [**Ettore Biondi**](https://www.linkedin.com/in/ettore-biondi/)
#     * Postdoctoral Researcher at California Institute of Technology in its Seismological Laboratory working within Professor Zhongwen Zhan's research group
#     * Former Ph.D. student at Stanford University in the Stanford Exporation Project (SEP) group
#     * Passionate about geophysics, computer science, chemistry, and Earth science
#     * Ettore's [personal page](http://www.seismolab.caltech.edu/biondi_e.html)
# * [**Stuart Farris**](https://www.linkedin.com/in/stuart-farris/)
#     * Ph.D. student at Stanford University in the Stanford Exporation Project (SEP) group
#     * Research interests: Carbon sequestration, machine learning, velocity model building using deep learning, seismic imaging, and inverse problems
#     * Currently an AI resident at [X Development](https://x.company)
#
# ---
# # Useful links
# * Our YouTube channel ["egoptimization"](https://www.youtube.com/channel/UCjloQO0H6JnddXoB017mcog)
# * Stanford Exploration project (SEP) [website](https://sep.sites.stanford.edu) and [YouTube channel](https://www.youtube.com/channel/UCk8h7bfpd-vl_CWCDLHxHzA)
# * Ettore's Ph.D. [thesis](http://sepwww.stanford.edu/data/media/public/sep/ettore/pdfs/thesis/thesis_Ettore.pdf) and Ph.D. [defense](https://www.youtube.com/watch?v=cmhhm4HW070&t=2645s) at Stanford University
# * Guillaume's Ph.D. [thesis](http://sepwww.stanford.edu/data/media/public/sep/gbarnier/Guillaume_thesis_sep_website.pdf) and Ph.D. [defense](https://www.youtube.com/watch?v=vv9krmVRkMo&t=2309s) at Stanford University
#
# ---
# # Description
# This Jupyter notebook allows you to reproduce the results proposed in Barnier et al. (2022) using the BP benchmark synthetic model (Billette and Brandsberg-Dahl, 2004). The notebook is organized as follows:
#  1. **Setup**:
#     * Import libraries
#     * Read/load initial/true velocity models (non-reproducible)
#     * Read/load the "target" velocity model, which is the FWIME inverted model shown in Barnier et al. (2022) that this notebook will allow you to reproduce
#     * Pad velocity models for FD modeling
#     * Create mask for gradient
#  2. **Conventional data-space mutli-scale FWI**
#      * Create wavelet sources and data
#      * Display wavelet time series, wavelet spectrum, and a subset of the dataset
#      * Launch inversion on each band
#      * Display objective functions and inverted model
#  3. **FWIME**
#      * For each inversion on a given spline grid:
#          * Map velocity model on current spline grid
#          * Create bounds for the mibn/max velocity values on current spline grid
#          * Launch inversion on current spline grid
#  4. **Results analysis**
#       * Display FWIME results (objective functions and inverted velocity models)
#  5. **References**

# %% [markdown]
# # Summary of main results
# * In this notebook, you will be able to reproduce the results from the numerical example proposed in Barnier et al. (2022) on the "Satl model" that we created by modifying the BP 2004 benchmark model (Billette and Brandsberg-Dahl, 2004)
# * In addition to the series of instructions which will allow you to reproduce our resutls, we provide:
#     * The initial model, which is very inaccruate (laterally invariant with an incorrect velocity trend)
#     * The true model
#     * The FWI inverted model shown in Barnier et al. (2022). You will also reproduce this result to see how poorly conventional FWI performs in this scenario
#     * The "target" FWIME model, which is the final FWIME inverted model shown in Barnier et al. (2022). At the end of the notebook, you should be able to receover the exact same model

# %% [markdown]
# ## Display velocity models to summarize results

# %%
# Import libraries
import genericIO
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
from scipy.ndimage import gaussian_filter
from matplotlib import pyplot as plt
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline
params = {
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 300,  # to adjust notebook inline plot size
    'axes.labelsize': 14, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 14, 
    'legend.fontsize': 12,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14
}
matplotlib.rcParams.update(params)

# Set the path for the executables
# %env ACO_GPU_PACK=/opt/acoustic_2d/local/

# Read velocity models
vel_true = genericIO.defaultIO.getVector("vel_non_repro/BP_Salt-trueVel.H")
vel_init = genericIO.defaultIO.getVector("vel_non_repro/BP_Salt-initVel1.H")
vel_fwime_paper = genericIO.defaultIO.getVector("vel_paper/BP_Salt_fwime_vel_paper.H")
vel_fwi_paper = genericIO.defaultIO.getVector("vel_paper/BP_Salt_fwi_vel_paper.H")

# Convert to np arrays
vel_fwime_paper_nd = vel_fwime_paper.getNdArray()
vel_fwi_paper_nd = vel_fwi_paper.getNdArray()
vel_true_nd = vel_true.getNdArray()
vel_init_nd = vel_init.getNdArray()
vel_hyper = vel_true.getHyper()

# Get model dimensions
oz = vel_hyper.getAxis(1).o
dz = vel_hyper.getAxis(1).d
nz = vel_hyper.getAxis(1).n
ox = vel_hyper.getAxis(2).o
dx = vel_hyper.getAxis(2).d
nx = vel_hyper.getAxis(2).n

fig, axs = plt.subplots(2, 2, figsize=(15, 15))

# Plot initial velocity model
img0_0 = axs[0,0].imshow(vel_init_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[0,0].set_title("Initial model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_0, ax=axs[0,0], orientation="horizontal", label="vel [km/s]")
axs[0,0].grid()

# Plot FWI velocity model
img0_1 = axs[0,1].imshow(vel_fwi_paper_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[0,1].set_title("FWI model from paper"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_1, ax=axs[0,1], orientation="horizontal", label="vel [km/s]")
axs[0,1].grid()

# Plot FWIME model
img1_0 = axs[1,0].imshow(vel_fwime_paper_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[1,0].set_title("FWIME model from paper"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img1_0, ax=axs[1,0], orientation="horizontal", label="vel [km/s]")
axs[1,0].grid()

# Plot true model
img1_1 = axs[1,1].imshow(vel_true_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[1,1].set_title("True model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img1_1, ax=axs[1,1], orientation="horizontal", label="vel [km/s]")
axs[1,1].grid()

plt.tight_layout()
# Out:
# env: ACO_GPU_PACK=/opt/acoustic_2d/local/

# %% [markdown]
# # Computational time
# To give you a sense of the computational time you should expect for the inversions proposed in this notebook, here are some estimations:
#
# 1. **Data-space multi-scale FWI**:
#     * We use four frequency bands
#     * We conduct 500 L-BFGS iterations per frequency band
#     * One L-BFGS iteration of FWI takes approximatelty 1 min on 4 x V100 Tesla NVIDIA GPUs
#     * The inversion on **one frequency band** takes approximately **8 hours**
# 2. **Model-space multi-scale FWIME**:
#     * We use **6 spline grids**
#     * One L-BFGS iteration of FWIME takes approximatelty 85 min on 4 x V100 Tesla NVIDIA GPUs
#     * For instance, the inversion on the first spline requires 90 L-BFGS iterations of FWIME, which corresponds to a compute time of approximately **127 hours**
#     * **Disclaimer**: The parameter values used in the paper and in this notebook are very conservative. Our goal was to "make it work" before trying to reduce the computational cost, as explained in Barnier et al. (2022)
#     * You are welcome to try to play with/adjust the FWIME parameters (in the "par" directory) to reduce the computational cost of FWIME, and observe their effects on the FWIME inverted model
#         * Decrease the number of linear iterations for the varaible projection step by setting "nIterLin" to a smaller value
#         * Decrease the number of L-BFGS iterations on each spline grid
#         * Decrease the extension length "nExt" from 101 to a smaller value

# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## Velocity models

# %%
# Read velocity models
vel_true = genericIO.defaultIO.getVector("vel_non_repro/BP_Salt-trueVel.H")
vel_init = genericIO.defaultIO.getVector("vel_non_repro/BP_Salt-initVel1.H")

# Get numpy array + hypecube info
vel_true_nd = vel_true.getNdArray()
vel_init_nd = vel_init.getNdArray()
vel_hyper = vel_true.getHyper()

# Get axes information
oz = vel_hyper.getAxis(1).o
dz = vel_hyper.getAxis(1).d
nz = vel_hyper.getAxis(1).n
ox = vel_hyper.getAxis(2).o
dx = vel_hyper.getAxis(2).d
nx = vel_hyper.getAxis(2).n

# %%
# Plot true velocity model
plt.figure(figsize=(15,5))
plt.imshow(vel_true_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect="equal")
plt.title("True model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
plt.colorbar(orientation="horizontal", label="vel [km/s]", aspect=50)
plt.grid()
plt.show()

# %%
# Plot initial velocity model
plt.figure(figsize=(15,5))
plt.imshow(vel_init_nd.T,cmap='jet', vmin=1.5, vmax=4.5, extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz),aspect="equal")
plt.title("Initial model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
plt.colorbar(orientation="horizontal", label="vel [km/s]", aspect=50)
plt.grid()
plt.show()

# %% [markdown]
# ## FWIME inverted velocity model from paper ("target" model)
# * These is the FWIME inverted velocity model presented in Barnier et al. (2022)
# * You should recover this solution after running this Jupyter notebook

# %%
# Read FWIME velocity model
vel_target = genericIO.defaultIO.getVector("vel_paper/BP_Salt_fwime_vel_paper.H")

# Get numpy array + hypercube info
vel_target_nd = vel_target.getNdArray()

# %%
# Plot FWIME velocity model
plt.figure(figsize=(15,5))
plt.imshow(vel_target_nd.T,cmap='jet', vmin=1.5, vmax=4.5, extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz),aspect="equal")
plt.title("FWIME 'target' model from paper"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
plt.colorbar(orientation="horizontal", label="vel [km/s]", aspect=50)
plt.grid()
plt.show()

# %% [markdown]
# ## Pad velocity models
# In this numerical example, we use absorbing boundaries in all directions

# %%
# %%bash
#
# # Pad both initial and true velocity models
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=vel_non_repro/BP_Salt-trueVel.H data=vel/BP_Salt-trueVel.pad.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=vel_non_repro/BP_Salt-initVel1.H data=vel/BP_Salt-initVel1.pad.H
# Out:
#
# ------------------------ Model padding program --------------------
# Original nz = 215 [samples]
# Original nx = 840 [samples]
#
# zPadMinus = 50 [samples]
# zPadPlus = 55 [samples]
# xPadMinus = 50 [samples]
# xPadPlus = 54 [samples]
#
# blockSize = 16 [samples]
# FAT = 5 [samples]
#
# New nz = 330 [samples including padding and FAT]
# New nx = 954 [samples including padding and FAT]
# -------------------------------------------------------------------
#
#
# ------------------------ Model padding program --------------------
# Original nz = 215 [samples]
# Original nx = 840 [samples]
#
# zPadMinus = 50 [samples]
# zPadPlus = 55 [samples]
# xPadMinus = 50 [samples]
# xPadPlus = 54 [samples]
#
# blockSize = 16 [samples]
# FAT = 5 [samples]
#
# New nz = 330 [samples including padding and FAT]
# New nx = 954 [samples including padding and FAT]
# -------------------------------------------------------------------

# %% [markdown]
# ## Masks for gradient
# * We generate different masks for the inversions on the different spline grids.
# * The same way we would create different masks for conventional data-space multi-scale FWI
# * The mask only restrains the inversion from updating the water layer
# * The "finer" the grid, the sharper the mask is in the vicinity of the water bottom

# %%
# %%bash
#
# ################# Mask for spline 1 #################
# # Create mask for gradient to prevent updates in the water layer
# Vel n1=215 n2=840 n3=1 d1=1 d2=1 d3=1 o1=0.0 o2=0.0 o3=0.0 vc=1 > temp/temp2.H &&\
# echo "d1=0.04 d2=0.04 d3=0.04" >> temp/temp2.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/temp2.H data=temp/temp2.pad.H &&\
# # Create mask
# ${ACO_GPU_PACK}/bin/maskGradientMain.py bufferUp=0.2 bufferDown=0.2 taperExp=2 wbShift=0.3 vel=vel/BP_Salt-trueVel.pad.H model=temp/temp2.pad.H data=temp/temp3.H mask=temp/tempMask1.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < temp/tempMask1.H > temp/tempMask2.H &&\
# Smooth rect2=2 < temp/tempMask2.H > temp/tempMask3.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/tempMask3.H data=vel/BP_Salt-gradMask1.pad.H &&\
#
# ################# Mask for spline 2 #################
# Vel n1=215 n2=840 n3=1 d1=1 d2=1 d3=1 o1=0.0 o2=0.0 o3=0.0 vc=1 > temp/temp2.H &&\
# echo "d1=0.04 d2=0.04 d3=0.04" >> temp/temp2.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/temp2.H data=temp/temp2.pad.H &&\
# # Create mask
# ${ACO_GPU_PACK}/bin/maskGradientMain.py bufferUp=0.2 bufferDown=0.2 taperExp=2 wbShift=0.0 vel=vel/BP_Salt-trueVel.pad.H model=temp/temp2.pad.H data=temp/temp3.H mask=temp/tempMask1.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < temp/tempMask1.H > temp/tempMask2.H &&\
# Smooth rect2=2 < temp/tempMask2.H > temp/tempMask3.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/tempMask3.H data=vel/BP_Salt-gradMask2.pad.H
# Out:
#
# ------------------------ Model padding program --------------------
# Original nz = 215 [samples]
# Original nx = 840 [samples]
#
# zPadMinus = 50 [samples]
# zPadPlus = 55 [samples]
# xPadMinus = 50 [samples]
# xPadPlus = 54 [samples]
#
# blockSize = 16 [samples]
# FAT = 5 [samples]
#
# New nz = 330 [samples including padding and FAT]
# New nx = 954 [samples including padding and FAT]
# -------------------------------------------------------------------
#
# --- User has not provided a gradient mask file ---
# --- Automatically generating the mask from the provided parameters ---
#
# ------------------------ Model padding program --------------------
# Original nz = 215 [samples]
# Original nx = 840 [samples]
#
# zPadMinus = 50 [samples]
# zPadPlus = 55 [samples]
# xPadMinus = 50 [samples]
# xPadPlus = 54 [samples]
#
# blockSize = 16 [samples]
# FAT = 5 [samples]
#
# New nz = 330 [samples including padding and FAT]
# New nx = 954 [samples including padding and FAT]
# ...

# %%
# Display mask
gradient_mask1 = genericIO.defaultIO.getVector("vel/BP_Salt-gradMask1.pad.H")
gradient_mask1_nd = gradient_mask1.getNdArray()
plt.figure(figsize=(15,5))
plt.imshow(gradient_mask1_nd.T,cmap='jet', vmin=-0.8, vmax=0.8, extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect="equal")
plt.title("True model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
plt.colorbar(orientation="horizontal", label="vel [km/s]", aspect=50)
plt.grid()
plt.show()

# %% [markdown]
# ## Create dummy velocity model
# We create this dummy file to pass the model dimension and hypercube information to the FWIME script and to the spline operator

# %%
# %%bash
#
# Cp vel/BP_Salt-trueVel.pad.H vel/BP_Salt_velDummy.pad.H

# %% [markdown]
# # 2. Conventional data-space multi-scale FWI

# %% [markdown]
# ## Create wavelets

# %% [markdown]
# For simplicity, we generate 5 wavelets and datasets corresponding to each frequency band instead of generating one dataset and bandpassing every time

# %%
# %%bash
#
# # Wavelet for FWI data-space multi-scale
# # 2-3 Hz
# ${ACO_GPU_PACK}/bin/waveletFloatMain.py par=par/BP_Salt-fwi-2-9.p timeDelay=2.0 f1=1.5 f2=2.5 f3=2.5 f4=3.5 type=ali wavelet=wav/BP_Salt-fwi-wav-2-3.H &&\
#
# # 2-4 Hz
# ${ACO_GPU_PACK}/bin/waveletFloatMain.py par=par/BP_Salt-fwi-2-9.p timeDelay=2.0 f1=1.5 f2=2.5 f3=3.0 f4=4.5 type=ali wavelet=wav/BP_Salt-fwi-wav-2-4.H &&\
#
# # 2-5 Hz
# ${ACO_GPU_PACK}/bin/waveletFloatMain.py par=par/BP_Salt-fwi-2-9.p timeDelay=2.0 f1=1.5 f2=2.5 f3=4.0 f4=5.5 type=ali wavelet=wav/BP_Salt-fwi-wav-2-5.H &&\
#
# # 2-7 Hz
# ${ACO_GPU_PACK}/bin/waveletFloatMain.py par=par/BP_Salt-fwi-2-9.p timeDelay=2.0 f1=1.5 f2=2.5 f3=5.0 f4=7.0 type=ali wavelet=wav/BP_Salt-fwi-wav-2-7.H &&\
#
# # 2-9 Hz
# ${ACO_GPU_PACK}/bin/waveletFloatMain.py par=par/BP_Salt-fwi-2-9.p timeDelay=2.0 f1=1.5 f2=2.5 f3=7.0 f4=9.0 type=ali wavelet=wav/BP_Salt-fwi-wav-2-9.H

# %% [markdown]
# ## Display wavelets time series

# %%
# Read wavelets 
wav_2_3 = genericIO.defaultIO.getVector("wav/BP_Salt-fwi-wav-2-3.H")
wav_2_4 = genericIO.defaultIO.getVector("wav/BP_Salt-fwi-wav-2-4.H")
wav_2_5 = genericIO.defaultIO.getVector("wav/BP_Salt-fwi-wav-2-5.H")
wav_2_7 = genericIO.defaultIO.getVector("wav/BP_Salt-fwi-wav-2-7.H")
wav_2_9 = genericIO.defaultIO.getVector("wav/BP_Salt-fwi-wav-2-9.H")

# Get numpy arrays
wav_2_3_nd = wav_2_3.getNdArray()
wav_2_4_nd = wav_2_4.getNdArray()
wav_2_5_nd = wav_2_5.getNdArray()
wav_2_7_nd = wav_2_7.getNdArray()
wav_2_9_nd = wav_2_9.getNdArray()

# Get dimensions
wavelet_hyper = wav_2_3.getHyper()
time_axis = wavelet_hyper.getAxis(1)
nt = time_axis.n
ot = time_axis.o
dt = time_axis.d

# Display wavelets in time
fig, ax = plt.subplots(figsize=(19,5))
time_range = np.linspace(ot, ot+(nt-1)*dt, nt)
plt.plot(time_range, wav_2_3_nd)
plt.plot(time_range, wav_2_4_nd)
plt.plot(time_range, wav_2_5_nd)
plt.plot(time_range, wav_2_7_nd)
plt.plot(time_range, wav_2_9_nd)
plt.title('Wavelet'), plt.xlabel("Time [s]"), plt.ylabel("Amplitude")
ax.autoscale(enable=True, axis='x', tight=True)
plt.ylim([-0.35, 0.35])
plt.xlim([1, 4])
plt.grid()
plt.show()

# %% [markdown]
# ## Plot wavelet spectra

# %%
# %%bash
#
# ############### Create wavelet spectra ###############
# Scale < wav/BP_Salt-fwi-wav-2-3.H | Spectra mag=dBnorm > temp/t1.H &&\
# Scale < wav/BP_Salt-fwi-wav-2-4.H | Spectra mag=dBnorm > temp/t2.H &&\
# Scale < wav/BP_Salt-fwi-wav-2-5.H | Spectra mag=dBnorm > temp/t3.H &&\
# Scale < wav/BP_Salt-fwi-wav-2-7.H | Spectra mag=dBnorm > temp/t4.H &&\
# Scale < wav/BP_Salt-fwi-wav-2-9.H | Spectra mag=dBnorm > temp/t5.H &&\
# Cat axis=2 temp/t1.H temp/t2.H temp/t3.H temp/t4.H temp/t5.H > wav/BP_Salt_temp_spec.H

# %%
# Read spectra
spectra = genericIO.defaultIO.getVector("wav/BP_Salt_temp_spec.H")
spectra_Nd = spectra.getNdArray()
spectraHyper = spectra.getHyper()

# Read dimensions
freq_axis = spectraHyper.getAxis(1)
nf = freq_axis.n
of = freq_axis.o
df = freq_axis.d

# Display wavelets in time
fig, ax = plt.subplots(figsize=(19,5))
freq_range = np.linspace(of, of+(nf-1)*df, nf)
plt.plot(freq_range, spectra_Nd.T)
plt.title('Wavelet spectra'), plt.xlabel("Frequency [Hz]"), plt.ylabel("Amplitude [dB]")
ax.autoscale(enable=True, axis='x', tight=True)
plt.ylim([-80, 5])
plt.xlim([0, 15])
plt.grid()
plt.show()

# %% [markdown]
# ## Generate data
# In this notebook, we generate noise-free acoustic isotropic constant-density pressure data

# %%
# %%bash
#
# # 2-3 Hz
# ${ACO_GPU_PACK}/bin/nonlinearPythonFloatMain.py par=par/BP_Salt-fwi-2-9.p vel=vel/BP_Salt-trueVel.pad.H model=wav/BP_Salt-fwi-wav-2-3.H data=dat/BP_Salt-fwi-dat-2-3.H info=0 &&\
#
# # 2-4 Hz
# ${ACO_GPU_PACK}/bin/nonlinearPythonFloatMain.py par=par/BP_Salt-fwi-2-9.p vel=vel/BP_Salt-trueVel.pad.H model=wav/BP_Salt-fwi-wav-2-4.H data=dat/BP_Salt-fwi-dat-2-4.H info=0 &&\
#
# # 2-5 Hz
# ${ACO_GPU_PACK}/bin/nonlinearPythonFloatMain.py par=par/BP_Salt-fwi-2-9.p vel=vel/BP_Salt-trueVel.pad.H model=wav/BP_Salt-fwi-wav-2-5.H data=dat/BP_Salt-fwi-dat-2-5.H info=0 &&\
#
# # 2-7 Hz
# ${ACO_GPU_PACK}/bin/nonlinearPythonFloatMain.py par=par/BP_Salt-fwi-2-9.p vel=vel/BP_Salt-trueVel.pad.H model=wav/BP_Salt-fwi-wav-2-7.H data=dat/BP_Salt-fwi-dat-2-7.H info=0 &&\
#
# # 2-9 Hz
# ${ACO_GPU_PACK}/bin/nonlinearPythonFloatMain.py par=par/BP_Salt-fwi-2-9.p vel=vel/BP_Salt-trueVel.pad.H model=wav/BP_Salt-fwi-wav-2-9.H data=dat/BP_Salt-fwi-dat-2-9.H info=0
# Out:
# -------------------------------------------------------------------
# ------------------ Running Python nonlinear forward ---------------
# -------------------- Single precision Python code -----------------
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# --------------------------- All done ------------------------------
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# ------------------ Running Python nonlinear forward ---------------
# -------------------- Single precision Python code -----------------
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# --------------------------- All done ------------------------------
# -------------------------------------------------------------------
#
# ...

# %% [markdown]
# ## Read and display data

# %%
# Read data
data_2_3 = genericIO.defaultIO.getVector("./dat/BP_Salt-fwi-dat-2-3.H")
data_2_4 = genericIO.defaultIO.getVector("./dat/BP_Salt-fwi-dat-2-4.H")
data_2_5 = genericIO.defaultIO.getVector("./dat/BP_Salt-fwi-dat-2-5.H")
data_2_7 = genericIO.defaultIO.getVector("./dat/BP_Salt-fwi-dat-2-7.H")
data_2_9 = genericIO.defaultIO.getVector("./dat/BP_Salt-fwi-dat-2-9.H")

# Display data
data_2_3_nd = data_2_3.getNdArray()
data_2_4_nd = data_2_4.getNdArray()
data_2_5_nd = data_2_5.getNdArray()
data_2_7_nd = data_2_7.getNdArray()
data_2_9_nd = data_2_9.getNdArray()

# Clipping
pclip=98
clip = np.percentile(np.abs(data_2_9_nd), pclip)

# Dimensions
o_rec = data_2_9.getHyper().getAxis(2).o
d_rec = data_2_9.getHyper().getAxis(2).d
n_rec = data_2_9.getHyper().getAxis(2).n
rec_range = np.linspace(o_rec, o_rec+(n_rec-1)*d_rec, n_rec)

# Display shot gathers
fig, axs = plt.subplots(2, 3, figsize=(20, 10))

# First frequency band: 4-6 Hz
shot1 = 30
axs[0,0].pcolormesh(rec_range, time_range, data_2_3_nd[shot1].T,vmin=-clip,vmax=clip)
axs[0,0].invert_yaxis()
axs[0,0].grid()
axs[0,0].set_ylabel('Time (s)')
axs[0,0].set_xlabel('Rec position (km)')
axs[0,0].set_title('Shot #' + str(shot1) + " (2-3 Hz)")

shot2 = 60
axs[0,1].pcolormesh(rec_range, time_range, data_2_3_nd[shot2].T,vmin=-clip,vmax=clip)
axs[0,1].invert_yaxis()
axs[0,1].grid()
axs[0,1].set_ylabel('Time (s)')
axs[0,1].set_xlabel('Rec position (km)')
axs[0,1].set_title('Shot #' + str(shot2) + " (2-3 Hz)")

shot3 = 90
axs[0,2].pcolormesh(rec_range, time_range, data_2_3_nd[shot3].T,vmin=-clip,vmax=clip)
axs[0,2].invert_yaxis()
axs[0,2].grid()
axs[0,2].set_ylabel('Time (s)')
axs[0,2].set_xlabel('Rec position (km)')
axs[0,2].set_title('Shot #' + str(shot3) + " (2-3 Hz)")

# Last frequency band: 4-13 Hz
axs[1,0].pcolormesh(rec_range, time_range, data_2_9_nd[shot1].T,vmin=-clip,vmax=clip)
axs[1,0].invert_yaxis()
axs[1,0].grid()
axs[1,0].set_ylabel('Time (s)')
axs[1,0].set_xlabel('Rec position (km)')
axs[1,0].set_title('Shot #' + str(shot1) + " (2-9 Hz)")

axs[1,1].pcolormesh(rec_range, time_range, data_2_9_nd[shot2].T,vmin=-clip,vmax=clip)
axs[1,1].invert_yaxis()
axs[1,1].grid()
axs[1,1].set_ylabel('Time (s)')
axs[1,1].set_xlabel('Rec position (km)')
axs[1,1].set_title('Shot #' + str(shot2) + " (2-9 Hz)")

axs[1,2].pcolormesh(rec_range, time_range, data_2_9_nd[shot3].T,vmin=-clip,vmax=clip)
axs[1,2].invert_yaxis()
axs[1,2].grid()
axs[1,2].set_ylabel('Time (s)')
axs[1,2].set_xlabel('Rec position (km)')
axs[1,2].set_title('Shot #' + str(shot3) + " (2-9 Hz)")

plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ## Conventional data-space multi-scale FWI
# * We apply conventional data-space multi-scale FWI using 5 frequency bands: 2-3 Hz, 2-4 Hz, 2-5 Hz, 2-7 Hz, and 2-9 Hz
# * We show that FWI converges to an unsatisfactory solution
# * The approximate computational time for one L-BFGS iteration of FWI is 1 min using 4 x V100 Tesla NVIDIA GPUs, so approximately **8 hours per frequency band** (500 iterations per band)

# %%
# %%bash
#
# # 2-3 Hz
# ${ACO_GPU_PACK}/bin/fwiMain.py par=par/BP_Salt-fwi-2-9.p sources=wav/BP_Salt-fwi-wav-2-3.H vel=vel/BP_Salt-initVel1.pad.H data=dat/BP_Salt-fwi-dat-2-3.H nIter=500 folder=inv/BP_Salt-fwi-2-3Hz minBound=1.3 maxBound=5.3 solver=lbfgs

# %%
# %%bash
#
# # 2-4 Hz
# ${ACO_GPU_PACK}/bin/fwiMain.py par=par/BP_Salt-fwi-2-9.p sources=wav/BP_Salt-fwi-wav-2-4.H vel=inv/BP_Salt-fwi-2-3Hz/BP_Salt-fwi-2-3Hz_inv_mod.H data=dat/BP_Salt-fwi-dat-2-4.H nIter=500 folder=inv/BP_Salt-fwi-2-4Hz minBound=1.3 maxBound=5.3 solver=lbfgs

# %%
# %%bash
#
# # 2-5 Hz
# ${ACO_GPU_PACK}/bin/fwiMain.py par=par/BP_Salt-fwi-2-9.p sources=wav/BP_Salt-fwi-wav-2-5.H vel=inv/BP_Salt-fwi-2-4Hz/BP_Salt-fwi-2-4Hz_inv_mod.H data=dat/BP_Salt-fwi-dat-2-5.H nIter=500 folder=inv/BP_Salt-fwi-2-5Hz minBound=1.3 maxBound=5.3 solver=lbfgs

# %%
# %%bash
#
# # 2-7 Hz
# ${ACO_GPU_PACK}/bin/fwiMain.py par=par/BP_Salt-fwi-2-9.p sources=wav/BP_Salt-fwi-wav-2-7.H vel=inv/BP_Salt-fwi-2-5Hz/BP_Salt-fwi-2-5Hz_inv_mod.H data=dat/BP_Salt-fwi-dat-2-7.H nIter=500 folder=inv/BP_Salt-fwi-2-7Hz minBound=1.3 maxBound=5.3 solver=lbfgs

# %%
# %%bash
#
# # 2-9 Hz
# ${ACO_GPU_PACK}/bin/fwiMain.py par=par/BP_Salt-fwi-2-9.p sources=wav/BP_Salt-fwi-wav-2-9.H vel=inv/BP_Salt-fwi-2-7Hz/BP_Salt-fwi-2-7Hz_inv_mod.H data=dat/BP_Salt-fwi-dat-2-9.H nIter=500 folder=inv/BP_Salt-fwi-2-9Hz minBound=1.3 maxBound=5.3 solver=lbfgs

# %% [markdown]
# ## Display FWI results

# %% [markdown]
# ### Objective functions

# %%
############# Objective functions #############
# Read file 
obj_fwi_2_3 = genericIO.defaultIO.getVector("inv/BP_Salt-fwi-2-3Hz/BP_Salt-fwi-2-3Hz_obj.H")
obj_fwi_2_4 = genericIO.defaultIO.getVector("inv/BP_Salt-fwi-2-4Hz/BP_Salt-fwi-2-4Hz_obj.H")
obj_fwi_2_5 = genericIO.defaultIO.getVector("inv/BP_Salt-fwi-2-5Hz/BP_Salt-fwi-2-5Hz_obj.H")
obj_fwi_2_7 = genericIO.defaultIO.getVector("inv/BP_Salt-fwi-2-7Hz/BP_Salt-fwi-2-7Hz_obj.H")
obj_fwi_2_9 = genericIO.defaultIO.getVector("inv/BP_Salt-fwi-2-9Hz/BP_Salt-fwi-2-9Hz_obj.H")

# Convert to numpy array
obj_fwi_2_3_nd = obj_fwi_2_3.getNdArray()
obj_fwi_2_4_nd = obj_fwi_2_4.getNdArray()
obj_fwi_2_5_nd = obj_fwi_2_5.getNdArray()
obj_fwi_2_7_nd = obj_fwi_2_7.getNdArray()
obj_fwi_2_9_nd = obj_fwi_2_9.getNdArray()

# Plot 
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.plot(obj_fwi_2_3_nd/obj_fwi_2_3_nd[0])
plt.xlabel("Iteration number",fontsize=14)
plt.ylabel("Scaled $\phi$",fontsize=14)
ax = plt.gca() 
plt.ylim([0,1])
plt.grid()
ax.autoscale(enable=True, axis='x', tight=True)
plt.subplot(122)
plt.plot(np.log10(obj_fwi_2_3_nd/obj_fwi_2_3_nd[0]))
plt.xlabel("Iteration number",fontsize=14)
plt.ylabel("Log10 scaled $\phi$",fontsize=14)
ax = plt.gca() 
plt.ylim([None,0])
plt.grid()
ax.autoscale(enable=True, axis='x', tight=True)
plt.tight_layout()

# %% [markdown]
# ### FWI inverted models for each frequency band

# %%
# %%bash
#
# # Remove padding from inverted models
# Window3d n1=215 f1=55 n2=840 f2=55 < inv/BP_Salt-fwi-2-3Hz/BP_Salt-fwi-2-3Hz_inv_mod.H > inv/BP_Salt_inv_mod_2_3.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < inv/BP_Salt-fwi-2-4Hz/BP_Salt-fwi-2-4Hz_inv_mod.H > inv/BP_Salt_inv_mod_2_4.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < inv/BP_Salt-fwi-2-5Hz/BP_Salt-fwi-2-5Hz_inv_mod.H > inv/BP_Salt_inv_mod_2_5.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < inv/BP_Salt-fwi-2-7Hz/BP_Salt-fwi-2-7Hz_inv_mod.H > inv/BP_Salt_inv_mod_2_7.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < inv/BP_Salt-fwi-2-9Hz/BP_Salt-fwi-2-9Hz_inv_mod.H > inv/BP_Salt_inv_mod_2_9.H

# %%
# Read inverted models
model_2_3 = genericIO.defaultIO.getVector("inv/BP_Salt_inv_mod_2_3.H")
model_2_4 = genericIO.defaultIO.getVector("inv/BP_Salt_inv_mod_2_4.H")
model_2_5 = genericIO.defaultIO.getVector("inv/BP_Salt_inv_mod_2_5.H")
model_2_7 = genericIO.defaultIO.getVector("inv/BP_Salt_inv_mod_2_7.H")
model_2_9 = genericIO.defaultIO.getVector("inv/BP_Salt_inv_mod_2_9.H")

# Convert to numpy arrays
model_2_3_nd = model_2_3.getNdArray()
model_2_4_nd = model_2_4.getNdArray()
model_2_5_nd = model_2_5.getNdArray()
model_2_7_nd = model_2_7.getNdArray()
model_2_9_nd = model_2_9.getNdArray()

fig, axs = plt.subplots(3, 2, figsize=(15, 15))

# Plot Initial velocity model
img0_0 = axs[0,0].imshow(vel_init_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[0,0].set_title("Initial"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_0, ax=axs[0,0], orientation="horizontal", label="vel [km/s]")
axs[0,0].grid()

# Plot 2-4 Hz velocity model
img0_1 = axs[0,1].imshow(model_2_4.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[0,1].set_title("FWI 4-6 Hz"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_1, ax=axs[0,1], orientation="horizontal", label="vel [km/s]")
axs[0,1].grid()

# Plot 2-5 Hz velocity model
img1_0 = axs[1,0].imshow(model_2_5_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[1,0].set_title("FWI 4-9 Hz"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img1_0, ax=axs[1,0], orientation="horizontal", label="vel [km/s]")
axs[1,0].grid()

# Plot 2-7 Hz velocity model
img1_1 = axs[1,1].imshow(model_2_7_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[1,1].set_title("FWI 4-11 Hz"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img1_1, ax=axs[1,1], orientation="horizontal", label="vel [km/s]")
axs[1,1].grid()

# Plot 2-9 Hz velocity model
img2_0 = axs[2,0].imshow(model_2_9_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[2,0].set_title("FWI 4-13 Hz"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img2_0, ax=axs[2,0], orientation="horizontal", label="vel [km/s]")
axs[2,0].grid()

# Plot true velocity model
img2_1 = axs[2,1].imshow(vel_true_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[2,1].set_title("True model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img2_1, ax=axs[2,1], orientation="horizontal", label="vel [km/s]")
axs[2,1].grid()


plt.tight_layout()

# %% [markdown]
# # 3. FWIME
# * We conduct a model-space multi-scale FWIME on 4 spline grids
# * One L-BFGS iteration of FWIME take approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs

# %% [markdown]
# ## Wavelet
# * The FWIME wavelet contains less low-frequency energy than for FWI to make the exercise even more difficult

# %%
# %%bash
#
# ############ Wavelet for FWIME ############
# # 4-13 Hz
# ${ACO_GPU_PACK}/bin/waveletFloatMain.py par=par/BP_Salt-fwime-3-9.p timeDelay=1.5 f1=3 f2=4 f3=7 f4=9 type=ali wavelet=wav/BP_Salt-fwime-wav-3-9.H

# %%
# Read wavelet
wav_fwime_3_9 = genericIO.defaultIO.getVector("wav/BP_Salt-fwime-wav-3-9.H")

# Get numpy arrays
wav_fwime_3_9_nd = wav_fwime_3_9.getNdArray()

# Get dimensions
wavelet_fwime_hyper = wav_fwime_3_9.getHyper()
time_axis_fwime = wavelet_fwime_hyper.getAxis(1)
nt_fwime = time_axis_fwime.n
ot_fwime = time_axis_fwime.o
dt_fwime = time_axis_fwime.d

# Display wavelets in time
fig, ax = plt.subplots(figsize=(19,5))
time_range_fwime = np.linspace(ot_fwime, ot_fwime+(nt_fwime-1)*dt_fwime, nt_fwime)
plt.plot(time_range_fwime, wav_fwime_3_9_nd)
plt.title('Wavelet for FWIME'), plt.xlabel("Time [s]"), plt.ylabel("Amplitude")
ax.autoscale(enable=True, axis='x', tight=True)
plt.ylim([-0.25, 0.25])
plt.xlim([0, 4])
plt.grid()
plt.show()

# %%
# %%bash
#
# ############### Create wavelet spectra ###############
# Scale < wav/BP_Salt-fwime-wav-3-9.H | Spectra mag=dBnorm > wav/BP_Salt_fwime_temp_spec.H

# %%
# Read spectra
spectra = genericIO.defaultIO.getVector("wav/BP_Salt_fwime_temp_spec.H")
spectra_Nd = spectra.getNdArray()
spectraHyper = spectra.getHyper()

# Read dimensions
freq_axis = spectraHyper.getAxis(1)
nf = freq_axis.n
of = freq_axis.o
df = freq_axis.d

# Display wavelets in time
fig, ax = plt.subplots(figsize=(19,5))
freq_range = np.linspace(of, of+(nf-1)*df, nf)
plt.plot(freq_range, spectra_Nd.T)
plt.title('FWIME wavelet spectrum '), plt.xlabel("Frequency [Hz]"), plt.ylabel("Amplitude [dB]")
ax.autoscale(enable=True, axis='x', tight=True)
plt.ylim([-80, 5])
plt.xlim([0, 15])
plt.grid()
plt.show()

# %% [markdown]
# ## Data
# * The FWIME data contain less low-frequency energy than for FWI to make the exercise even more difficult

# %%
# %%bash
#
# ############ Data ############
# ${ACO_GPU_PACK}/bin/nonlinearPythonFloatMain.py par=par/BP_Salt-fwime-3-9.p vel=vel/BP_Salt-trueVel.pad.H model=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H info=0 nGpu=4
# Out:
# -------------------------------------------------------------------
# ------------------ Running Python nonlinear forward ---------------
# -------------------- Single precision Python code -----------------
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# --------------------------- All done ------------------------------
# -------------------------------------------------------------------
# /opt/conda/lib/python3.7/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
# Read data
data_3_9_fwime = genericIO.defaultIO.getVector("dat/BP_Salt-fwime-data-3-9.H")

# Display data
data_3_9_fwime_nd = data_3_9_fwime.getNdArray()

# Clipping
pclip=98
clip = np.percentile(np.abs(data_3_9_fwime_nd), pclip)

# Dimensions
o_rec_fwime = data_3_9_fwime.getHyper().getAxis(2).o
d_rec_fwime = data_3_9_fwime.getHyper().getAxis(2).d
n_rec_fwime = data_3_9_fwime.getHyper().getAxis(2).n
rec_range_fwime = np.linspace(o_rec_fwime, o_rec_fwime+(n_rec_fwime-1)*d_rec_fwime, n_rec_fwime)

# Display shot gathers
fig, axs = plt.subplots(1, 3, figsize=(20, 10))

shot1 = 30
axs[0].pcolormesh(rec_range_fwime, time_range_fwime, data_3_9_fwime_nd[shot1].T,vmin=-clip,vmax=clip)
axs[0].invert_yaxis()
axs[0].grid()
axs[0].set_ylabel('Time (s)')
axs[0].set_xlabel('Rec position (km)')
axs[0].set_title('Shot #' + str(shot1) + " (3-9 Hz)")

shot2 = 60
axs[1].pcolormesh(rec_range_fwime, time_range_fwime, data_3_9_fwime_nd[shot2].T,vmin=-clip,vmax=clip)
axs[1].invert_yaxis()
axs[1].grid()
axs[1].set_ylabel('Time (s)')
axs[1].set_xlabel('Rec position (km)')
axs[1].set_title('Shot #' + str(shot2) + " (3-9 Hz)")

shot3 = 90
axs[2].pcolormesh(rec_range_fwime, time_range_fwime, data_3_9_fwime_nd[shot3].T,vmin=-clip,vmax=clip)
axs[2].invert_yaxis()
axs[2].grid()
axs[2].set_ylabel('Time (s)')
axs[2].set_xlabel('Rec position (km)')
axs[2].set_title('Shot #' + str(shot3) + " (3-9 Hz)")

plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# ## Upper and lower velocity bounds computation
# * We choose lower/upper velocity values $v_{min}$ and $v_{max}$ to prevent the velocity model from taking values that would create FD instability or dispersion
# * However, the step length calculation and the model updates are conducted on the spline grid (see Barnier et. al, 2022), so we need to express these bounds on the spline grid
# * For each spline grid, we create two constant velocity models on the FD grid whose values are set to $v_{min}$ and $v_{max}$, respectively
# * We map these constant velocity models onto the spline grid by applying the adjoint of the spline mapping operator
# * We use the output of this adjoint mapping as lower/upper bounds on the spline grid (which is where our unknown model is parametrized)

# %%
# %%bash
#
# ################### Bounds for spline grid 1 ###################
# # Max bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=5.0 > temp/junkMax.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMax.H data=temp/junkMax.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMax.pad.H model=vel/BP_Salt-fwime-3-9-spline1-maxBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline1.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# # Min bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=1.3 > temp/junkMin.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMin.H data=temp/junkMin.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMin.pad.H model=vel/BP_Salt-fwime-3-9-spline1-minBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline1.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# ################### Bounds for spline grid 2 ###################
# # Max bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=5.0 > temp/junkMax.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMax.H data=temp/junkMax.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMax.pad.H model=vel/BP_Salt-fwime-3-9-spline2b-maxBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline2b.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# # Min bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=1.3 > temp/junkMin.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMin.H data=temp/junkMin.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMin.pad.H model=vel/BP_Salt-fwime-3-9-spline2b-minBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline2b.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# ################### Bounds for spline grid 3 ###################
# # Max bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=5.0 > temp/junkMax.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMax.H data=temp/junkMax.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMax.pad.H model=vel/BP_Salt-fwime-3-9-spline2-maxBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline2.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# # Min bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=1.3 > temp/junkMin.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMin.H data=temp/junkMin.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMin.pad.H model=vel/BP_Salt-fwime-3-9-spline2-minBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline2.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# ################### Bounds for spline grid 4 ###################
# # Max bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=5.0 > temp/junkMax.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMax.H data=temp/junkMax.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMax.pad.H model=vel/BP_Salt-fwime-3-9-spline3-maxBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline3.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# # Min bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=1.3 > temp/junkMin.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMin.H data=temp/junkMin.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMin.pad.H model=vel/BP_Salt-fwime-3-9-spline3-minBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline3.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# ################### Bounds for spline grid 5 ###################
# # Max bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=5.0 > temp/junkMax.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMax.H data=temp/junkMax.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMax.pad.H model=vel/BP_Salt-fwime-3-9-spline4-maxBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline4.p vel=vel/BP_Salt_velDummy.pad.H &&\
#
# # Min bound
# Vel n1=215 n2=840 n3=1 d1=0.04 d2=0.04 d3=0.04 vc=1.3 > temp/junkMin.H &&\
# ${ACO_GPU_PACK}/bin/padFileGpuMain zPad=50 xPad=50 model=temp/junkMin.H data=temp/junkMin.pad.H &&\
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 data=temp/junkMin.pad.H model=vel/BP_Salt-fwime-3-9-spline4-minBound.H adj=1 par=par/BP_Salt-fwime-3-9-spline4.p vel=vel/BP_Salt_velDummy.pad.H

# %% [markdown]
# ## FWIME on spline grid 1

# %% [markdown]
# ### Generate initial model onto first spline grid
# * In step II of this notebook, we created/read the initial velocity model $\mathbf{m}^f_{init}$ defined on the (fine) FD grid
# * We now need to convert it (or map it) onto the first coarse spline grid $c_1$ in order to obtain the initial model for the FWIME inversion, $\mathbf{m}^{c_1}_{init}$
# * The mapping is done by finding the unique minimizer of the following loss function:
#
# $\mathbf{m}^{c_1}_{init} = \underset{\mathbf{m}^{c_1}}{\mathrm{argmin}} \; \dfrac{1}{2} \left \| \mathbf{S}_1 \mathbf{m}^{c_1} - \mathbf{m}^f_{init} \right \|_2^2$
# * $\mathbf{S}_1$ is the spline mapping operator (from the first coarse spline grid -> fine grid)
# * $\mathbf{m}^{c_1}$ corresponds to any model defined on the first spline grid

# %%
# %%bash
#
# # Create directory spline2dJunk (you might have to create it manually by typing "mkdir spline2dJunk")
# # Map initial model onto the first spline grid
# ${ACO_GPU_PACK}/bin/interpBSplineInvMain.py nDim=2 nIter=50 folder=spline2dJunk vel=vel/BP_Salt_velDummy.pad.H data=vel/BP_Salt-initVel1.pad.H par=par/BP_Salt-fwime-3-9-spline1.p &&\
# Cp spline2dJunk/spline2dJunk_inv_mod.H vel/BP_Salt-fwime-3-9-coarseInitMod-spline1.H

# %% [markdown]
# ### Launch inversion on spline grid 1
# * Conduct 90 L-BFGS iterations on spline grid 1
# * One L-BFGS iteration of FWIME take approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs, so **127 hours** for 90 iterations

# %%
# %%bash
#
# # Launch inversion
# ${ACO_GPU_PACK}/bin/fwimeMain.py par=par/BP_Salt-fwime-3-9-spline1.p vel=vel/BP_Salt_velDummy.pad.H sources=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H folderNl=inv/BP_Salt-fwime-3-9-spline1 modelCoarseInit=vel/BP_Salt-fwime-3-9-coarseInitMod-spline1.H minBoundVector=vel/BP_Salt-fwime-3-9-spline1-minBound.H maxBoundVector=vel/BP_Salt-fwime-3-9-spline1-maxBound.H epsilon=2.5e-4 sloth=1
# Out:
# Process is terminated.

# %% [markdown]
# ## FWIME on spline grid 2

# %% [markdown]
# ### Map inverted model: spline 1 -> spline 2
# * The output of FWIME on the first spline grid $\mathbf{m}^{c_1}_{final}$ is mapped onto the FD grid:
#
# $\mathbf{m}^f_{1} = \mathbf{S}_1 \mathbf{m}^{c_1}_{final}$
#
# * Then, the analogous inversion procedure as the one done in the previous step is employed to map this model on the second spline grid:
#
# $\mathbf{m}^{c_2}_{init} = \underset{\mathbf{m}^{c_2}}{\mathrm{argmin}} \; \dfrac{1}{2} \left \| \mathbf{S}_2 \mathbf{m}^{c_2} - \mathbf{m}^f_{1} \right \|_2^2$

# %%
# %%bash
#
# Window3d n3=1 f3=0 < inv/BP_Salt-fwime-3-9-spline1/BP_Salt-fwime-3-9-spline1_inv_mod.H > temp/junk1.H &&\
# # Map inverted model from spline 2b -> FD grid
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 vel=vel/BP_Salt_velDummy.pad.H model=temp/junk1.H data=vel/BP_Salt-fwime-inv-mod-spline1.pad.H adj=0 par=par/BP_Salt-fwime-3-9-spline1.p &&\
# # Map inverted model from FD grid -> spline 2b
# ${ACO_GPU_PACK}/bin/interpBSplineInvMain.py nDim=2 nIter=50 folder=spline2dJunk vel=vel/BP_Salt_velDummy.pad.H data=vel/BP_Salt-fwime-inv-mod-spline1.pad.H par=par/BP_Salt-fwime-3-9-spline2b.p &&\
# Cp spline2dJunk/spline2dJunk_inv_mod.H vel/BP_Salt-fwime-3-9-coarseInitMod-spline2b.H

# %% [markdown]
# ### Launch inversion on spline grid 2
# * Conduct 30 L-BFGS iterations on spline grid 2
# * One L-BFGS iteration of FWIME take approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs, so **42 hours** for 30 iterations

# %%
# %%bash
#
# # Launch inversion
# ${ACO_GPU_PACK}/bin/fwimeMain.py par=par/BP_Salt-fwime-3-9-spline2b.p vel=vel/BP_Salt_velDummy.pad.H sources=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H folderNl=inv/BP_Salt-fwime-3-9-spline2b modelCoarseInit=vel/BP_Salt-fwime-3-9-coarseInitMod-spline2b.H minBoundVector=vel/BP_Salt-fwime-3-9-spline2b-minBound.H maxBoundVector=vel/BP_Salt-fwime-3-9-spline2b-maxBound.H epsilon=2.5e-4 sloth=1

# %% [markdown]
# ## FWIME on spline grid 3

# %% [markdown]
# ### Map inverted model on spline 2 -> spline 3

# %%
# %%bash
#
# # Extract inverted model from spline 2b inversion
# Window3d n3=1 f3=0 < inv/BP_Salt-fwime-3-9-spline2b/BP_Salt-fwime-3-9-spline2b_inv_mod.H > temp/junk1.H &&\
# # Map inverted model from spline 2b -> FD grid
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 vel=vel/BP_Salt_velDummy.pad.H model=temp/junk1.H data=vel/BP_Salt-fwime-inv-mod-spline2b.pad.H adj=0 par=par/BP_Salt-fwime-3-9-spline2b.p &&\
# # Map inverted model from FD grid -> spline 2
# ${ACO_GPU_PACK}/bin/interpBSplineInvMain.py nDim=2 nIter=50 folder=spline2dJunk vel=vel/BP_Salt_velDummy.pad.H data=vel/BP_Salt-fwime-inv-mod-spline2b.pad.H par=par/BP_Salt-fwime-3-9-spline2.p &&\
# Cp spline2dJunk/spline2dJunk_inv_mod.H vel/BP_Salt-fwime-3-9-coarseInitMod-spline2.H

# %% [markdown]
# ### Launch inversion on spline grid 3
# * Conduct 40 L-BFGS iterations on spline grid 3
# * One L-BFGS iteration of FWIME takes approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs, so **56 hours** for 40 iterations

# %%
# %%bash
#
# ${ACO_GPU_PACK}/bin/fwimeMain.py par=par/BP_Salt-fwime-3-9-spline2.p vel=vel/BP_Salt_velDummy.pad.H sources=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H folderNl=inv/BP_Salt-fwime-3-9-spline2 modelCoarseInit=vel/BP_Salt-fwime-3-9-coarseInitMod-spline2.H minBoundVector=vel/BP_Salt-fwime-3-9-spline2-minBound.H maxBoundVector=vel/BP_Salt-fwime-3-9-spline2-maxBound.H epsilon=2.5e-4 sloth=1

# %% [markdown]
# ## FWIME on spline grid 4

# %% [markdown]
# ### Map inverted model on spline 3 into spline 4
# * The analogous procdure is employed to map the inverted model on spline 3 -> spline 4

# %%
# %%bash
#
# # Extract inverted model
# Window3d n3=1 f3=0 < inv/BP_Salt-fwime-3-9-spline2/BP_Salt-fwime-3-9-spline2_inv_mod.H > temp/junk1.H &&\
# # Map inverted model -> FD grid
# ${ACO_GPU_PACK}/${B}/interpBSplineMain.py nDim=2 vel=vel/BP_Salt_velDummy.pad.H model=temp/junk1.H data=vel/BP_Salt-fwime-inv-mod-spline2.pad.H adj=0 par=par/BP_Salt-fwime-3-9-spline2.p &&\
# # Map inverted model from FD grid to coarse grid
# ${ACO_GPU_PACK}/${B}/interpBSplineInvMain.py nDim=2 nIter=50 folder=spline2dJunk vel=vel/BP_Salt_velDummy.pad.H data=vel/BP_Salt-fwime-inv-mod-spline2.pad.H par=par/BP_Salt-fwime-3-9-spline3.p &&\
# Cp spline2dJunk/spline2dJunk_inv_mod.H $@

# %% [markdown]
# ### Launch inversion on fourth spline grid (FD grid)
# * Conduct 22 L-BFGS iterations on spline grid 4 (FD grid)
# * One L-BFGS iteration of FWIME takes approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs, so **31 hours** for 22 iterations

# %%
# %%bash
#
# ${ACO_GPU_PACK}/bin/fwimeMain.py par=par/BP_Salt-fwime-3-9-spline3.p vel=vel/BP_Salt_velDummy.pad.H sources=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H folderNl=inv/BP_Salt-fwime-3-9-spline3 modelCoarseInit=vel/BP_Salt-fwime-3-9-coarseInitMod-spline3.H minBoundVector=vel/BP_Salt-fwime-3-9-spline3-minBound.H maxBoundVector=vel/BP_Salt-fwime-3-9-spline3-maxBound.H epsilon=2.5e-4 sloth=1

# %% [markdown]
# ## FWIME on spline grid 5

# %% [markdown]
# ### Map inverted model on spline 4 into spline 5
# * The analogous procdure is employed to map the inverted model on spline 4 -> spline 5

# %%
# %%bash
#
# Window3d n3=1 f3=0 < inv/BP_Salt-fwime-3-9-spline4/BP_Salt-fwime-3-9-spline4_inv_mod.H > temp/junk1.H &&\
# # Map inverted model from spline 3 -> FD grid
# ${ACO_GPU_PACK}/bin/interpBSplineMain.py nDim=2 vel=vel/BP_Salt_velDummy.pad.H model=temp/junk1.H data=vel/BP_Salt-fwime-inv-mod-spline3.pad.H adj=0 par=par/BP_Salt-fwime-3-9-spline3.p &&\
# # Map inverted model from FD grid -> spline 4
# ${ACO_GPU_PACK}/bin/interpBSplineInvMain.py nDim=2 nIter=50 folder=spline2dJunk vel=vel/BP_Salt_velDummy.pad.H data=vel/BP_Salt-fwime-inv-mod-spline3.pad.H par=par/BP_Salt-fwime-3-9-spline4.p &&\
# Cp spline2dJunk/spline2dJunk_inv_mod.H vel/BP_Salt-fwime-3-9-coarseInitMod-spline4.H

# %% [markdown]
# ### Launch inversion on spline grid 5
# * Conduct 30 L-BFGS iterations on spline grid 5
# * One L-BFGS iteration of FWIME take approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs, so **40 hours** for 30 iterations

# %%
# %%bash
#
# ${ACO_GPU_PACK}/bin/fwimeMain.py par=par/BP_Salt-fwime-3-9-spline4.p vel=vel/BP_Salt_velDummy.pad.H sources=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H folderNl=inv/BP_Salt-fwime-3-9-spline4 modelCoarseInit=vel/BP_Salt-fwime-3-9-coarseInitMod-spline4.H minBoundVector=vel/BP_Salt-fwime-3-9-spline4-minBound.H maxBoundVector=vel/BP_Salt-fwime-3-9-spline4-maxBound.H epsilon=2.5e-4 sloth=1

# %% [markdown]
# ## FWIME on spline grid 6 (FD grid)

# %% [markdown]
# ### Map inverted model on spline 5 -> spline 6
# * The analogous procdure is employed to map the inverted model on spline 5 -> spline 6

# %%
# %%bash
#
# Window3d n3=1 f3=0 < inv/BP_Salt-fwime-3-9-spline4/BP_Salt-fwime-3-9-spline4_inv_mod.H > temp/junk1.H &&\
# # Map inverted model from spline 4 -> FD grid
# ${ACO_GPU_PACK}/bin/interpBSplineIterMain.py nDim=2 vel=vel/BP_Salt-velDummy.pad.H model=temp/junk1.H data=vel/BP_Salt-fwime-inv-mod-spline4.pad.H adj=0 par=par/BP_Salt-fwime-3-9-spline4.p

# %% [markdown]
# ### Launch inversion on spline grid 6 (FD grid)
# * Conduct 100 L-BFGS iterations on spline grid 6 (FD grid)
# * One L-BFGS iteration of FWIME takes approximately 85 minutes on 4 x V100 Tesla NVIDIA GPUs, so **140 hours** for 100 iterations

# %%
# %%bash
#
# ${ACO_GPU_PACK}/bin/fwimeMain.py par=par/BP_Salt-fwime-3-9-noSpline.p vel=vel/BP_Salt-fwime-3-9-coarseInitMod-noSpline.H sources=wav/BP_Salt-fwime-wav-3-9.H data=dat/BP_Salt-fwime-data-3-9.H folderNl=inv/BP_Salt-fwime-3-9-noSpline minBound=1.3 maxBound=5.0 epsilon=2.5e-4 sloth=1

# %% [markdown]
# # 4. FWIME results analysis

# %% [markdown]
# ## FWIME objective functions

# %% [markdown]
# ### Concatenate all components of objective functions

# %%
# %%bash
#
# # Concatenate all objective functions components?
# Cat axis=1 inv/BP_Salt-fwime-3-9-spline1/BP_Salt-fwime-3-9-spline1_obj.H inv/BP_Salt-fwime-3-9-spline2b/BP_Salt-fwime-3-9-spline2b_obj.H inv/BP_Salt-fwime-3-9-spline2/BP_Salt-fwime-3-9-spline2_obj.H inv/BP_Salt-fwime-3-9-spline3/BP_Salt-fwime-3-9-spline3_obj.H inv/BP_Salt-fwime-3-9-spline4/BP_Salt-fwime-3-9-spline4_obj.H inv/BP_Salt-fwime-3-9-noSpline/BP_Salt-fwime-3-9-noSpline_obj.H > inv/BP_Salt_fwime_obj_total.H &&\
# Cat axis=1 inv/BP_Salt-fwime-3-9-spline1/BP_Salt-fwime-3-9-spline1_obj_comp1.H inv/BP_Salt-fwime-3-9-spline2b/BP_Salt-fwime-3-9-spline2b_obj_comp1.H inv/BP_Salt-fwime-3-9-spline2/BP_Salt-fwime-3-9-spline2_obj_comp1.H inv/BP_Salt-fwime-3-9-spline3/BP_Salt-fwime-3-9-spline3_obj_comp1.H inv/BP_Salt-fwime-3-9-spline4/BP_Salt-fwime-3-9-spline4_obj_comp1.H inv/BP_Salt-fwime-3-9-noSpline/BP_Salt-fwime-3-9-noSpline_obj_comp1.H > inv/BP_Salt_fwime_obj_data.H &&\
# Cat axis=1 inv/BP_Salt-fwime-3-9-spline1/BP_Salt-fwime-3-9-spline1_obj_comp2.H inv/BP_Salt-fwime-3-9-spline2b/BP_Salt-fwime-3-9-spline2b_obj_comp2.H inv/BP_Salt-fwime-3-9-spline2/BP_Salt-fwime-3-9-spline2_obj_comp1.H inv/BP_Salt-fwime-3-9-spline3/BP_Salt-fwime-3-9-spline3_obj_comp2.H inv/BP_Salt-fwime-3-9-spline4/BP_Salt-fwime-3-9-spline4_obj_comp2.H inv/BP_Salt-fwime-3-9-noSpline/BP_Salt-fwime-3-9-noSpline_obj_comp2.H > inv/BP_Salt_fwime_obj_annihilator.H

# %% [markdown]
# ### Read and display objective function

# %%
# Read FWIME objective functions

# Spline 1
fwime_obj_total = genericIO.defaultIO.getVector("inv/BP_Salt_fwime_obj_total.H")
fwime_obj_data = genericIO.defaultIO.getVector("inv/BP_Salt_fwime_obj_data.H")
fwime_obj_annihilator = genericIO.defaultIO.getVector("inv/BP_Salt_fwime_obj_annihilator.H")

# Convert from SEP arrays to numpy arrays
fwime_obj_total_nd = fwime_obj_total.getNdArray()
fwime_obj_data_nd = fwime_obj_data.getNdArray()
fwime_obj_annihilator_nd = fwime_obj_annihilator.getNdArray()

# Plot normalized objective function
fwime_obj_total_norm = fwime_obj_total_nd/fwime_obj_total_nd[0]
fwime_obj_data_norm = fwime_obj_data_nd/fwime_obj_total_nd[0]
fwime_obj_annihilator_norm = fwime_obj_annihilator_nd/fwime_obj_total_nd[0]
plt.figure(figsize=(10,4))

# Display wavelets in time
fig, ax = plt.subplots(figsize=(19,5))
time_range = np.linspace(ot, ot+(nt-1)*dt, nt)
plt.plot(fwime_obj_total_norm)
plt.plot(fwime_obj_data_norm)
plt.plot(fwime_obj_annihilator_norm)
plt.title('FWIME objective function'), plt.xlabel("Iteration #"), plt.ylabel("Normalized objective function value")
ax.autoscale(enable=True, axis='x', tight=True)
plt.ylim([0 1])
plt.xlim([0, 300])
plt.grid()
plt.show()

# %% [markdown]
# ## FWIME inverted models

# %%
# %%bash
#
# # Extract and crop inverted models on each spline grids
# Window3d n1=215 f1=55 n2=840 f2=55 < vel/BP_Salt-fwime-inv-mod-spline1.pad.H > vel/BP_Salt-fwime-inv-mod-spline1.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < vel/BP_Salt-fwime-inv-mod-spline2.pad.H > vel/BP_Salt-fwime-inv-mod-spline2.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < vel/BP_Salt-fwime-inv-mod-spline3.pad.H > vel/BP_Salt-fwime-inv-mod-spline3.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < vel/BP_Salt-fwime-inv-mod-spline4.pad.H > vel/BP_Salt-fwime-inv-mod-spline4.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < vel/BP_Salt-fwime-inv-mod-spline5.pad.H > vel/BP_Salt-fwime-inv-mod-spline5.H &&\
# Window3d n1=215 f1=55 n2=840 f2=55 < inv/BP_Salt-fwime-3-9-noSpline/BP_Salt-fwime-3-9-noSpline_inv_mod.H > vel/BP_Salt-fwime-inv-mod-noSpline.H

# %%
# Read inverted models

vel_true = genericIO.defaultIO.getVector("vel/BP_Salt-trueVel.H")
vel_init = genericIO.defaultIO.getVector("vel/BP_Salt-initVel1.H")
model_fwi = genericIO.defaultIO.getVector("BP_Salt_inv_mod_2_3.H")
model_fwime_s1 = genericIO.defaultIO.getVector("vel/BP_Salt-fwime-inv-mod-spline1.H")
model_fwime_s2 = genericIO.defaultIO.getVector("vel/BP_Salt-fwime-inv-mod-spline2.H")
model_fwime_s3 = genericIO.defaultIO.getVector("vel/BP_Salt-fwime-inv-mod-spline3.H")
model_fwime_s4 = genericIO.defaultIO.getVector("vel/BP_Salt-fwime-inv-mod-spline4.H")
model_fwime_s5 = genericIO.defaultIO.getVector("vel/BP_Salt-fwime-inv-mod-spline5.H")
model_fwime_noSpline = genericIO.defaultIO.getVector("vel/BP_Salt-fwime-inv-mod-noSpline.H")

# Convert to numpy arrays
vel_true_nd = vel_true.getNdArray()
vel_init_nd = vel_init.getNdArray()
model_fwi_nd = model_fwi.getNdArray()
model_fwime_s1_nd = model_fwime_s1.getNdArray()
model_fwime_s2_nd = model_fwime_s2.getNdArray()
model_fwime_s3_nd = model_fwime_s3.getNdArray()
model_fwime_s4_nd = model_fwime_s4.getNdArray()
model_fwime_s5_nd = model_fwime_s5.getNdArray()
model_fwime_noSpline_nd = model_fwime_noSpline.getNdArray()

fig, axs = plt.subplots(3, 2, figsize=(15, 15))

# Plot true velocity model
img0_0 = axs[0,0].imshow(vel_init_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[0,0].set_title("Initial model"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_0, ax=axs[0,0], orientation="horizontal", label="vel [km/s]")
axs[0,0].grid()
# plt.show()

# Plot initial velocity model
img0_1 = axs[0,1].imshow(model_fwi_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[0,1].set_title("FWI 4-13 Hz"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_1, ax=axs[0,1], orientation="horizontal", label="vel [km/s]")
axs[0,1].grid()
# plt.show()

# Plot true velocity model
img1_0 = axs[1,0].imshow(model_fwime_s1_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[1,0].set_title("FWIME spline 1"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img1_0, ax=axs[1,0], orientation="horizontal", label="vel [km/s]")
axs[1,0].grid()
# plt.show()

# Plot initial velocity model
img1_1 = axs[1,1].imshow(model_fwime_s2_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[1,1].set_title("FWIME spline 2"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img0_1, ax=axs[1,1], orientation="horizontal", label="vel [km/s]")
axs[1,1].grid()
# plt.show()

# Plot true velocity model
img2_0 = axs[2,0].imshow(model_fwime_noSpline.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[2,0].set_title("FWIME FD grid"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img2_0, ax=axs[2,0], orientation="horizontal", label="vel [km/s]")
axs[2,0].grid()
# plt.show()

# Plot true velocity model
img2_1 = axs[2,1].imshow(vel_true_nd.T,cmap='jet', vmin=vel_true_nd.min(), vmax=vel_true_nd.max(), extent=(ox, (ox+(nx-1)*dx), (oz+(nz-1)*dz), oz), aspect=1.5)
axs[2,1].set_title("True velocity"), plt.xlabel("x [km]"), plt.ylabel("z [km]")
fig.colorbar(img2_1, ax=axs[2,1], orientation="horizontal", label="vel [km/s]")
axs[2,1].grid()
# plt.show()

plt.tight_layout()

# %% [markdown]
# ## VI. References

# %% [markdown]
# * Billette, F., and S. Brandsberg-Dahl, 2005, The 2004 bp velocity benchmark: 67th EAGE Conference & Exhibition, European Association of Geoscientists & Engineers, cp–1.
#
# * Barnier, G., E. Biondi, R. G. Clapp, and B. Biondi, 2022, Full waveform inversion by model extension: practical applications (manuscript submitted to Geophysics)
